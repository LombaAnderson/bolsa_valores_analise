# %%
import pandas as pd
pd.set_option('display.min_rows', 50)
pd.set_option('display.max_rows',200)

# %%
def busca_carteira_teorica(indice):
    url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
    return pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1]

# %%
ibov = busca_carteira_teorica('ibov')

# %%
ibov.sort_values('Part. (%)',ascending=False)
# Out:
#                 Ação      Tipo Qtde. Teórica  Part. (%)
# Código
# VALE3           VALE     ON NM    3218796397     10.985
# ITUB4   ITAUUNIBANCO     PN N1    4757466114      6.082
# PETR4      PETROBRAS     PN N2    4566457037      5.472
# B3SA3             B3     ON NM    1700747480      5.284
# BBDC4       BRADESCO     PN N1    4261649634      4.736
# PETR3      PETROBRAS     ON N2    3509328784      4.261
# MGLU3    MAGAZ LUIZA     ON NM     668758001      3.226
# ABEV3      AMBEV S/A        ON    4355174839      3.083
# WEGE3            WEG     ON NM     674731315      2.315
# ITSA4         ITAUSA     PN N1    4515538171      2.247
# GNDI3    INTERMEDICA     ON NM     581199237      2.233
# BBAS3         BRASIL  ON EJ NM    1283197221      2.226
# NTCO3   GRUPO NATURA     ON NM     719775531      2.074
# JBSS3            JBS     ON NM    1568829515      2.021
# SUZB3    SUZANO S.A.     ON NM     724921241      2.009
# LREN3   LOJAS RENNER     ON NM     785417914      1.836
# RENT3       LOCALIZA  ON EJ NM     594568300      1.735
# RAIL3      RUMO S.A.     ON NM    1348000144      1.593
# VVAR3      VIAVAREJO     ON NM    1594758941      1.538
# UGPA3       ULTRAPAR     ON NM    1088225414      1.382
# BRDT3   PETROBRAS BR     ON NM    1164958126      1.380
# RADL3   RAIADROGASIL  ON EB NM    1071470660      1.370
# LAME4   LOJAS AMERIC     PN N1     835033880      1.359
# BBDC3       BRADESCO     ON N1    1253093907      1.302
# EQTL3     EQUATORIAL     ON NM    1010286085      1.274
# GGBR4         GERDAU     PN N1     995903643      1.155
# BTOW3    B2W DIGITAL     ON NM     208209427      1.085
# VIVT4   TELEF BRASIL        PN     415131868      1.070
# BPAC11    BTGP BANCO    UNT N2     236093794      0.990
# BBSE3   BBSEGURIDADE     ON NM     671584841      0.952
# BRFS3         BRF SA     ON NM     811759800      0.941
# SBSP3         SABESP     ON NM     339999111      0.893
# KLBN11    KLABIN S/A    UNT N2     637999310      0.889
# CCRO3         CCR SA     ON NM    1115695556      0.855
# HAPV3        HAPVIDA  ON EJ NM     217045654      0.754
# TOTS3          TOTVS     ON NM     480228410      0.752
# HYPE3         HYPERA     ON NM     410147968      0.686
# PCAR3   P.ACUCAR-CBD     ON NM     156831174      0.654
# ELET3     ELETROBRAS     ON N1     358018408      0.642
# TIMP3   TIM PART S/A     ON NM     808343726      0.628
# SULA11   SUL AMERICA    UNT N2     279572852      0.616
# ENGI11      ENERGISA    UNT N2     250679709      0.597
# EGIE3   ENGIE BRASIL     ON NM     254792279      0.594
# CSNA3   SID NACIONAL        ON     642398790      0.583
# CMIG4          CEMIG     PN N1     969723092      0.571
# COGN3       COGNA ON     ON NM    1847994874      0.566
# BRAP4      BRADESPAR     PN N1     222075664      0.561
# SANB11  SANTANDER BR       UNT     355666691      0.538
# CSAN3          COSAN     ON NM     129314042      0.530
# AZUL4           AZUL     PN N2     326903173      0.510
# QUAL3      QUALICORP     ON NM     283408928      0.501
# FLRY3         FLEURY     ON NM     303800430      0.493
# YDUQ3     YDUQS PART     ON NM     300483575      0.488
# CRFB3   CARREFOUR BR     ON NM     391758726      0.459
# ELET6     ELETROBRAS    PNB N1     240019548      0.445
# BRML3   BR MALLS PAR     ON NM     843728684      0.439
# IRBR3   IRBBRASIL RE     ON NM    1255352371      0.390
# GOAU4     GERDAU MET     PN N1     693699918      0.362
# CYRE3   CYRELA REALT     ON NM     281154098      0.358
# TAEE11         TAESA    UNT N2     218568274      0.341
# MULT3      MULTIPLAN     ON N2     276848567      0.338
# MRFG3        MARFRIG     ON NM     368864634      0.335
# BRKM5        BRASKEM    PNA N1     264640575      0.319
# USIM5       USIMINAS    PNA N1     513781576      0.312
# CPFE3   CPFL ENERGIA     ON NM     187714249      0.301
# ENBR3    ENERGIAS BR     ON NM     294036156      0.294
# PRIO3       PETRORIO     ON NM     135160900      0.285
# EMBR3        EMBRAER     ON NM     736160905      0.272
# MRVE3            MRV     ON NM     298796441      0.269
# CIEL3          CIELO     ON NM    1112196638      0.262
# EZTC3          EZTEC     ON NM      95756217      0.200
# BEEF3        MINERVA     ON NM     259565738      0.189
# IGTA3       IGUATEMI     ON NM      85796919      0.168
# GOLL4            GOL     PN N2     137716367      0.153
# CVCB3     CVC BRASIL     ON NM     149183975      0.143
# HGTX3     CIA HERING     ON NM     126186408      0.126
# ECOR3    ECORODOVIAS     ON NM     171109276      0.123

# %%
smll = busca_carteira_teorica('smll')

# %%
smll
# Out:
#                 Ação      Tipo Qtde. Teórica  Part. (%)
# Código
# AALR3         ALLIAR     ON NM      46716473      0.166
# ABCB4     ABC BRASIL     PN N2      72844643      0.302
# ALSO3   ALIANSCSONAE     ON NM     127376805      1.078
# ALUP11        ALUPAR    UNT N2     143808703      1.079
# AMAR3   LOJAS MARISA     ON NM     111476495      0.293
# ANIM3          ANIMA     ON NM      68226108      0.626
# ARZZ3      AREZZO CO     ON NM      45095471      0.783
# AZUL4           AZUL     PN N2     326903173      2.938
# BEEF3        MINERVA     ON NM     259565738      1.087
# BIDI11   BANCO INTER    UNT N2     152011291      2.642
# BIDI4    BANCO INTER     PN N2      27985633      0.165
# BKBR3      BK BRASIL     ON NM     224801207      0.834
# BMGB4      BANCO BMG     PN N1     102705124      0.164
# BPAN4      BANCO PAN     PN N1     383124068      1.034
# BRAP4      BRADESPAR     PN N1     222075664      3.231
# BRML3   BR MALLS PAR     ON NM     843728684      2.527
# BRPR3     BR PROPERT     ON NM     198812616      0.599
# BRSR6       BANRISUL    PNB N1     202531540      0.802
# CAML3          CAMIL     ON NM     120754497      0.518
# CEAB3      CEA MODAS     ON NM     106396035      0.440
# CESP6           CESP    PNB N1     182017689      1.661
# CNTO3       CENTAURO     ON NM      88628266      0.776
# COGN3       COGNA ON     ON NM    1847994874      3.256
# CSMG3         COPASA     ON NM      62814853      0.983
# CVCB3     CVC BRASIL     ON NM     149183975      0.821
# CYRE3   CYRELA REALT     ON NM     281154098      2.062
# DIRR3     DIRECIONAL     ON NM      81360368      0.368
# DMMO3          DOMMO        ON     269966315      0.101
# DTEX3        DURATEX     ON NM     273421574      1.519
# ECOR3    ECORODOVIAS     ON NM     171109276      0.708
# EMBR3        EMBRAER     ON NM     736160905      1.567
# ENAT3    ENAUTA PART     ON NM      75939767      0.264
# ENBR3    ENERGIAS BR     ON NM     294036156      1.694
# ENEV3          ENEVA     ON NM     315416873      5.114
# EVEN3           EVEN     ON NM     209535948      0.781
# EZTC3          EZTEC     ON NM      95756217      1.154
# FLRY3         FLEURY     ON NM     303800430      2.838
# GFSA3         GAFISA     ON NM     175805879      0.241
# GOAU4     GERDAU MET     PN N1     693699918      2.087
# GOLL4            GOL     PN N2     137716367      0.882
# GRND3       GRENDENE     ON NM     271473296      0.651
# GUAR3     GUARARAPES        ON      86115120      0.443
# HBOR3         HELBOR     ON NM      65261522      0.228
# HGTX3     CIA HERING     ON NM     126186408      0.728
# IGTA3       IGUATEMI     ON NM      85796919      0.969
# IRBR3   IRBBRASIL RE     ON NM    1255352371      2.248
# JHSF3      JHSF PART     ON NM     293161476      0.696
# LCAM3     LOCAMERICA  ON EJ NM     323763077      2.238
# LEVE3     METAL LEVE     ON NM      38492519      0.214
# LIGT3      LIGHT S/A     ON NM     303934060      1.413
# LINX3           LINX     ON NM     149946789      1.706
# LOGG3   LOG COM PROP     ON NM      59735959      0.609
# LOGN3         LOG-IN     ON NM     100109944      0.557
# LPSB3   LOPES BRASIL     ON NM     114874308      0.205
# LWSA3        LOCAWEB     ON NM      82490635      1.543
# MDIA3   M.DIASBRANCO     ON NM      83669782      0.992
# MEAL3        IMC S/A     ON NM     266523532      0.290
# MILS3          MILLS     ON NM     115485533      0.240
# MOVI3         MOVIDA     ON NM     132113940      0.735
# MRFG3        MARFRIG     ON NM     368864634      1.931
# MRVE3            MRV     ON NM     298796441      1.549
# MULT3      MULTIPLAN     ON N2     276848567      1.947
# MYPK3   IOCHP-MAXION     ON NM     141465625      0.638
# ODPV3     ODONTOPREV  ON EJ NM     263492832      1.064
# OMGE3      OMEGA GER     ON NM     101852143      1.255
# PARD3      IHPARDINI  ON EJ NM      45066096      0.341
# POMO4      MARCOPOLO     PN N2     573419889      0.532
# POSI3   POSITIVO TEC     ON NM      78616498      0.118
# PRIO3       PETRORIO     ON NM     135160900      1.641
# QUAL3      QUALICORP     ON NM     283408928      2.887
# RAPT4    RANDON PART     PN N1     176269235      0.677
# RLOG3      COSAN LOG     ON NM     122209783      0.783
# SAPR11       SANEPAR    UNT N2     200991234      1.712
# SAPR4        SANEPAR     PN N2     203503821      0.346
# SEER3      SER EDUCA     ON NM      54346207      0.278
# SIMH3         SIMPAR     ON NM      55040438      0.516
# SLCE3   SLC AGRICOLA     ON NM      86086214      0.727
# SMLS3         SMILES     ON NM      58842428      0.306
# SMTO3   SAO MARTINHO     ON NM     143032073      1.069
# SQIA3         SINQIA     ON NM      58796282      0.434
# STBP3     SANTOS BRP     ON NM     664964456      1.059
# TAEE11         TAESA    UNT N2     218568274      1.964
# TASA4   TAURUS ARMAS     PN N2      40032007      0.113
# TCSA3        TECNISA     ON NM      54617458      0.173
# TEND3          TENDA     ON NM      96408761      0.878
# TGMA3          TEGMA     ON NM      32007080      0.247
# TIET11   AES TIETE E    UNT N2     301873417      1.414
# TRIS3         TRISUL     ON NM      78643944      0.292
# TUPY3           TUPY     ON NM      65992011      0.335
# USIM5       USIMINAS    PNA N1     513781576      1.794
# VIVA3    VIVARA S.A.     ON NM      93368726      0.700
# VLID3          VALID     ON NM      68358698      0.199
# VULC3      VULCABRAS     ON NM      74685291      0.145
# WIZS3       WIZ S.A.     ON NM      77453769      0.237
# YDUQ3     YDUQS PART     ON NM     300483575      2.809

# %%
ibrx = busca_carteira_teorica('ibrx')

# %%
ibrx
# Out:
#                 Ação      Tipo Qtde. Teórica  Part. (%)
# Código
# ABEV3      AMBEV S/A        ON    4355174839      2.857
# ALPA4     ALPARGATAS     PN N1     168770200      0.303
# ALSO3   ALIANSCSONAE     ON NM     127376805      0.173
# AMAR3   LOJAS MARISA     ON NM     111476495      0.047
# AZUL4           AZUL     PN N2     326903173      0.473
# B3SA3             B3     ON NM    2043531244      5.883
# BBAS3         BRASIL  ON EJ NM    1283197221      2.062
# BBDC3       BRADESCO     ON N1    1253093907      1.206
# BBDC4       BRADESCO     PN N1    4261649634      4.389
# BBSE3   BBSEGURIDADE     ON NM     671584841      0.882
# BEEF3        MINERVA     ON NM     259565738      0.175
# BIDI4    BANCO INTER     PN N2      27985633      0.026
# BPAC11    BTGP BANCO    UNT N2     236093794      0.917
# BPAN4      BANCO PAN     PN N1     383124068      0.166
# BRAP4      BRADESPAR     PN N1     222075664      0.520
# BRDT3   PETROBRAS BR     ON NM    1164958126      1.279
# BRFS3         BRF SA     ON NM     811759800      0.872
# BRKM5        BRASKEM    PNA N1     264640575      0.296
# BRML3   BR MALLS PAR     ON NM     843728684      0.407
# BTOW3    B2W DIGITAL     ON NM     208209427      1.006
# CCRO3         CCR SA     ON NM    1115695556      0.792
# CESP6           CESP    PNB N1     182017689      0.267
# CIEL3          CIELO     ON NM    1112196638      0.243
# CMIG4          CEMIG     PN N1     969723092      0.529
# CNTO3       CENTAURO     ON NM      88628266      0.125
# COGN3       COGNA ON     ON NM    1847994874      0.524
# CPFE3   CPFL ENERGIA     ON NM     187714249      0.279
# CPLE6          COPEL    PNB N1     128297543      0.421
# CRFB3   CARREFOUR BR     ON NM     391758726      0.426
# CSAN3          COSAN     ON NM     129314042      0.491
# CSMG3         COPASA     ON NM      62814853      0.158
# CSNA3   SID NACIONAL        ON     642398790      0.540
# CVCB3     CVC BRASIL     ON NM     149183975      0.132
# CYRE3   CYRELA REALT     ON NM     281154098      0.332
# DTEX3        DURATEX     ON NM     273421574      0.245
# ECOR3    ECORODOVIAS     ON NM     171109276      0.114
# EGIE3   ENGIE BRASIL     ON NM     254792279      0.550
# ELET3     ELETROBRAS     ON N1     358018408      0.595
# ELET6     ELETROBRAS    PNB N1     240019548      0.412
# EMBR3        EMBRAER     ON NM     736160905      0.252
# ENBR3    ENERGIAS BR     ON NM     294036156      0.273
# ENEV3          ENEVA     ON NM     315416873      0.823
# ENGI11      ENERGISA    UNT N2     250679709      0.553
# EQTL3     EQUATORIAL     ON NM    1010286085      1.180
# EZTC3          EZTEC     ON NM      95756217      0.186
# FLRY3         FLEURY     ON NM     303800430      0.457
# GGBR4         GERDAU     PN N1     995903643      1.071
# GNDI3    INTERMEDICA     ON NM     581199237      2.069
# GOAU4     GERDAU MET     PN N1     693699918      0.336
# GOLL4            GOL     PN N2     137716367      0.142
# HAPV3        HAPVIDA  ON EJ NM     217045654      0.698
# HGTX3     CIA HERING     ON NM     126186408      0.117
# HYPE3         HYPERA     ON NM     410147968      0.636
# IGTA3       IGUATEMI     ON NM      85796919      0.156
# IRBR3   IRBBRASIL RE     ON NM    1255352371      0.362
# ITSA4         ITAUSA     PN N1    4515538171      2.082
# ITUB4   ITAUUNIBANCO     PN N1    4757466114      5.636
# JBSS3            JBS     ON NM    1568829515      1.872
# JHSF3      JHSF PART     ON NM     293161476      0.112
# KLBN11    KLABIN S/A    UNT N2     637999310      0.824
# LAME3   LOJAS AMERIC     ON N1     243346695      0.316
# LAME4   LOJAS AMERIC     PN N1     835033880      1.259
# LCAM3     LOCAMERICA  ON EJ NM     323763077      0.360
# LIGT3      LIGHT S/A     ON NM     303934060      0.227
# LINX3           LINX     ON NM     149946789      0.275
# LREN3   LOJAS RENNER     ON NM     785417914      1.702
# MDIA3   M.DIASBRANCO     ON NM      83669782      0.160
# MGLU3    MAGAZ LUIZA     ON NM     668758001      2.989
# MOVI3         MOVIDA     ON NM     132113940      0.118
# MRFG3        MARFRIG     ON NM     368864634      0.311
# MRVE3            MRV     ON NM     298796441      0.249
# MULT3      MULTIPLAN     ON N2     276848567      0.313
# NEOE3     NEOENERGIA     ON NM     226115915      0.208
# NTCO3   GRUPO NATURA     ON NM     719775531      1.921
# PCAR3   P.ACUCAR-CBD     ON NM     156831174      0.606
# PETR3      PETROBRAS     ON N2    3684060179      4.145
# PETR4      PETROBRAS     PN N2    4566457037      5.070
# PRIO3       PETRORIO     ON NM     135160900      0.264
# PSSA3   PORTO SEGURO     ON NM      93637072      0.241
# QUAL3      QUALICORP     ON NM     283408928      0.465
# RADL3   RAIADROGASIL  ON EB NM    1071470660      1.269
# RAIL3      RUMO S.A.     ON NM    1348000144      1.476
# RAPT4    RANDON PART     PN N1     176269235      0.109
# RENT3       LOCALIZA  ON EJ NM     594568300      1.607
# SANB11  SANTANDER BR       UNT     355666691      0.499
# SAPR11       SANEPAR    UNT N2     200991234      0.276
# SBSP3         SABESP     ON NM     339999111      0.828
# SULA11   SUL AMERICA    UNT N2     279572852      0.571
# SUZB3    SUZANO S.A.     ON NM     724921241      1.861
# TAEE11         TAESA    UNT N2     218568274      0.316
# TIMP3   TIM PART S/A     ON NM     808343726      0.582
# TOTS3          TOTVS     ON NM     480228410      0.697
# TRPL4   TRAN PAULIST     PN N1     395797044      0.432
# UGPA3       ULTRAPAR     ON NM    1088225414      1.281
# USIM5       USIMINAS    PNA N1     513781576      0.289
# VALE3           VALE     ON NM    3330750414     10.533
# VIVT4   TELEF BRASIL        PN     415131868      0.991
# VVAR3      VIAVAREJO     ON NM    1594758941      1.425
# WEGE3            WEG     ON NM     741148001      2.356
# YDUQ3     YDUQS PART     ON NM     300483575      0.452

# %%
pd.concat([ibov,ibrx], keys=['IBOV', 'IBRX'], axis=1)
# Out:
#                 IBOV                                            IBRX  \
#                 Ação      Tipo Qtde. Teórica Part. (%)          Ação
# ABEV3      AMBEV S/A        ON    4355174839     3.083     AMBEV S/A
# AZUL4           AZUL     PN N2     326903173     0.510          AZUL
# B3SA3             B3     ON NM    1700747480     5.284            B3
# BBAS3         BRASIL  ON EJ NM    1283197221     2.226        BRASIL
# BBDC3       BRADESCO     ON N1    1253093907     1.302      BRADESCO
# BBDC4       BRADESCO     PN N1    4261649634     4.736      BRADESCO
# BBSE3   BBSEGURIDADE     ON NM     671584841     0.952  BBSEGURIDADE
# BEEF3        MINERVA     ON NM     259565738     0.189       MINERVA
# BPAC11    BTGP BANCO    UNT N2     236093794     0.990    BTGP BANCO
# BRAP4      BRADESPAR     PN N1     222075664     0.561     BRADESPAR
# BRDT3   PETROBRAS BR     ON NM    1164958126     1.380  PETROBRAS BR
# BRFS3         BRF SA     ON NM     811759800     0.941        BRF SA
# BRKM5        BRASKEM    PNA N1     264640575     0.319       BRASKEM
# BRML3   BR MALLS PAR     ON NM     843728684     0.439  BR MALLS PAR
# BTOW3    B2W DIGITAL     ON NM     208209427     1.085   B2W DIGITAL
# CCRO3         CCR SA     ON NM    1115695556     0.855        CCR SA
# CIEL3          CIELO     ON NM    1112196638     0.262         CIELO
# CMIG4          CEMIG     PN N1     969723092     0.571         CEMIG
# COGN3       COGNA ON     ON NM    1847994874     0.566      COGNA ON
# CPFE3   CPFL ENERGIA     ON NM     187714249     0.301  CPFL ENERGIA
# CRFB3   CARREFOUR BR     ON NM     391758726     0.459  CARREFOUR BR
# CSAN3          COSAN     ON NM     129314042     0.530         COSAN
# CSNA3   SID NACIONAL        ON     642398790     0.583  SID NACIONAL
# CVCB3     CVC BRASIL     ON NM     149183975     0.143    CVC BRASIL
# CYRE3   CYRELA REALT     ON NM     281154098     0.358  CYRELA REALT
# ECOR3    ECORODOVIAS     ON NM     171109276     0.123   ECORODOVIAS
# EGIE3   ENGIE BRASIL     ON NM     254792279     0.594  ENGIE BRASIL
# ELET3     ELETROBRAS     ON N1     358018408     0.642    ELETROBRAS
# ELET6     ELETROBRAS    PNB N1     240019548     0.445    ELETROBRAS
# EMBR3        EMBRAER     ON NM     736160905     0.272       EMBRAER
# ENBR3    ENERGIAS BR     ON NM     294036156     0.294   ENERGIAS BR
# ENGI11      ENERGISA    UNT N2     250679709     0.597      ENERGISA
# EQTL3     EQUATORIAL     ON NM    1010286085     1.274    EQUATORIAL
# EZTC3          EZTEC     ON NM      95756217     0.200         EZTEC
# FLRY3         FLEURY     ON NM     303800430     0.493        FLEURY
# GGBR4         GERDAU     PN N1     995903643     1.155        GERDAU
# GNDI3    INTERMEDICA     ON NM     581199237     2.233   INTERMEDICA
# GOAU4     GERDAU MET     PN N1     693699918     0.362    GERDAU MET
# GOLL4            GOL     PN N2     137716367     0.153           GOL
# HAPV3        HAPVIDA  ON EJ NM     217045654     0.754       HAPVIDA
# HGTX3     CIA HERING     ON NM     126186408     0.126    CIA HERING
# HYPE3         HYPERA     ON NM     410147968     0.686        HYPERA
# IGTA3       IGUATEMI     ON NM      85796919     0.168      IGUATEMI
# IRBR3   IRBBRASIL RE     ON NM    1255352371     0.390  IRBBRASIL RE
# ITSA4         ITAUSA     PN N1    4515538171     2.247        ITAUSA
# ITUB4   ITAUUNIBANCO     PN N1    4757466114     6.082  ITAUUNIBANCO
# JBSS3            JBS     ON NM    1568829515     2.021           JBS
# KLBN11    KLABIN S/A    UNT N2     637999310     0.889    KLABIN S/A
# LAME4   LOJAS AMERIC     PN N1     835033880     1.359  LOJAS AMERIC
# LREN3   LOJAS RENNER     ON NM     785417914     1.836  LOJAS RENNER
# MGLU3    MAGAZ LUIZA     ON NM     668758001     3.226   MAGAZ LUIZA
# MRFG3        MARFRIG     ON NM     368864634     0.335       MARFRIG
# MRVE3            MRV     ON NM     298796441     0.269           MRV
# MULT3      MULTIPLAN     ON N2     276848567     0.338     MULTIPLAN
# NTCO3   GRUPO NATURA     ON NM     719775531     2.074  GRUPO NATURA
# PCAR3   P.ACUCAR-CBD     ON NM     156831174     0.654  P.ACUCAR-CBD
# PETR3      PETROBRAS     ON N2    3509328784     4.261     PETROBRAS
# PETR4      PETROBRAS     PN N2    4566457037     5.472     PETROBRAS
# PRIO3       PETRORIO     ON NM     135160900     0.285      PETRORIO
# QUAL3      QUALICORP     ON NM     283408928     0.501     QUALICORP
# RADL3   RAIADROGASIL  ON EB NM    1071470660     1.370  RAIADROGASIL
# RAIL3      RUMO S.A.     ON NM    1348000144     1.593     RUMO S.A.
# RENT3       LOCALIZA  ON EJ NM     594568300     1.735      LOCALIZA
# SANB11  SANTANDER BR       UNT     355666691     0.538  SANTANDER BR
# SBSP3         SABESP     ON NM     339999111     0.893        SABESP
# SULA11   SUL AMERICA    UNT N2     279572852     0.616   SUL AMERICA
# SUZB3    SUZANO S.A.     ON NM     724921241     2.009   SUZANO S.A.
# TAEE11         TAESA    UNT N2     218568274     0.341         TAESA
# TIMP3   TIM PART S/A     ON NM     808343726     0.628  TIM PART S/A
# TOTS3          TOTVS     ON NM     480228410     0.752         TOTVS
# UGPA3       ULTRAPAR     ON NM    1088225414     1.382      ULTRAPAR
# USIM5       USIMINAS    PNA N1     513781576     0.312      USIMINAS
# VALE3           VALE     ON NM    3218796397    10.985          VALE
# VIVT4   TELEF BRASIL        PN     415131868     1.070  TELEF BRASIL
# VVAR3      VIAVAREJO     ON NM    1594758941     1.538     VIAVAREJO
# WEGE3            WEG     ON NM     674731315     2.315           WEG
# YDUQ3     YDUQS PART     ON NM     300483575     0.488    YDUQS PART
# ALPA4            NaN       NaN           NaN       NaN    ALPARGATAS
# ALSO3            NaN       NaN           NaN       NaN  ALIANSCSONAE
# AMAR3            NaN       NaN           NaN       NaN  LOJAS MARISA
# BIDI4            NaN       NaN           NaN       NaN   BANCO INTER
# BPAN4            NaN       NaN           NaN       NaN     BANCO PAN
# CESP6            NaN       NaN           NaN       NaN          CESP
# CNTO3            NaN       NaN           NaN       NaN      CENTAURO
# CPLE6            NaN       NaN           NaN       NaN         COPEL
# CSMG3            NaN       NaN           NaN       NaN        COPASA
# DTEX3            NaN       NaN           NaN       NaN       DURATEX
# ENEV3            NaN       NaN           NaN       NaN         ENEVA
# JHSF3            NaN       NaN           NaN       NaN     JHSF PART
# LAME3            NaN       NaN           NaN       NaN  LOJAS AMERIC
# LCAM3            NaN       NaN           NaN       NaN    LOCAMERICA
# LIGT3            NaN       NaN           NaN       NaN     LIGHT S/A
# LINX3            NaN       NaN           NaN       NaN          LINX
# MDIA3            NaN       NaN           NaN       NaN  M.DIASBRANCO
# MOVI3            NaN       NaN           NaN       NaN        MOVIDA
# NEOE3            NaN       NaN           NaN       NaN    NEOENERGIA
# PSSA3            NaN       NaN           NaN       NaN  PORTO SEGURO
# RAPT4            NaN       NaN           NaN       NaN   RANDON PART
# SAPR11           NaN       NaN           NaN       NaN       SANEPAR
# TRPL4            NaN       NaN           NaN       NaN  TRAN PAULIST
#
#
#             Tipo Qtde. Teórica Part. (%)
# ABEV3         ON    4355174839     2.857
# AZUL4      PN N2     326903173     0.473
# B3SA3      ON NM    2043531244     5.883
# BBAS3   ON EJ NM    1283197221     2.062
# BBDC3      ON N1    1253093907     1.206
# BBDC4      PN N1    4261649634     4.389
# BBSE3      ON NM     671584841     0.882
# BEEF3      ON NM     259565738     0.175
# BPAC11    UNT N2     236093794     0.917
# BRAP4      PN N1     222075664     0.520
# BRDT3      ON NM    1164958126     1.279
# BRFS3      ON NM     811759800     0.872
# BRKM5     PNA N1     264640575     0.296
# BRML3      ON NM     843728684     0.407
# BTOW3      ON NM     208209427     1.006
# CCRO3      ON NM    1115695556     0.792
# CIEL3      ON NM    1112196638     0.243
# CMIG4      PN N1     969723092     0.529
# COGN3      ON NM    1847994874     0.524
# CPFE3      ON NM     187714249     0.279
# CRFB3      ON NM     391758726     0.426
# CSAN3      ON NM     129314042     0.491
# CSNA3         ON     642398790     0.540
# CVCB3      ON NM     149183975     0.132
# CYRE3      ON NM     281154098     0.332
# ECOR3      ON NM     171109276     0.114
# EGIE3      ON NM     254792279     0.550
# ELET3      ON N1     358018408     0.595
# ELET6     PNB N1     240019548     0.412
# EMBR3      ON NM     736160905     0.252
# ENBR3      ON NM     294036156     0.273
# ENGI11    UNT N2     250679709     0.553
# EQTL3      ON NM    1010286085     1.180
# EZTC3      ON NM      95756217     0.186
# FLRY3      ON NM     303800430     0.457
# GGBR4      PN N1     995903643     1.071
# GNDI3      ON NM     581199237     2.069
# GOAU4      PN N1     693699918     0.336
# GOLL4      PN N2     137716367     0.142
# HAPV3   ON EJ NM     217045654     0.698
# HGTX3      ON NM     126186408     0.117
# HYPE3      ON NM     410147968     0.636
# IGTA3      ON NM      85796919     0.156
# IRBR3      ON NM    1255352371     0.362
# ITSA4      PN N1    4515538171     2.082
# ITUB4      PN N1    4757466114     5.636
# JBSS3      ON NM    1568829515     1.872
# KLBN11    UNT N2     637999310     0.824
# LAME4      PN N1     835033880     1.259
# LREN3      ON NM     785417914     1.702
# MGLU3      ON NM     668758001     2.989
# MRFG3      ON NM     368864634     0.311
# MRVE3      ON NM     298796441     0.249
# MULT3      ON N2     276848567     0.313
# NTCO3      ON NM     719775531     1.921
# PCAR3      ON NM     156831174     0.606
# PETR3      ON N2    3684060179     4.145
# PETR4      PN N2    4566457037     5.070
# PRIO3      ON NM     135160900     0.264
# QUAL3      ON NM     283408928     0.465
# RADL3   ON EB NM    1071470660     1.269
# RAIL3      ON NM    1348000144     1.476
# RENT3   ON EJ NM     594568300     1.607
# SANB11       UNT     355666691     0.499
# SBSP3      ON NM     339999111     0.828
# SULA11    UNT N2     279572852     0.571
# SUZB3      ON NM     724921241     1.861
# TAEE11    UNT N2     218568274     0.316
# TIMP3      ON NM     808343726     0.582
# TOTS3      ON NM     480228410     0.697
# UGPA3      ON NM    1088225414     1.281
# USIM5     PNA N1     513781576     0.289
# VALE3      ON NM    3330750414    10.533
# VIVT4         PN     415131868     0.991
# VVAR3      ON NM    1594758941     1.425
# WEGE3      ON NM     741148001     2.356
# YDUQ3      ON NM     300483575     0.452
# ALPA4      PN N1     168770200     0.303
# ALSO3      ON NM     127376805     0.173
# AMAR3      ON NM     111476495     0.047
# BIDI4      PN N2      27985633     0.026
# BPAN4      PN N1     383124068     0.166
# CESP6     PNB N1     182017689     0.267
# CNTO3      ON NM      88628266     0.125
# CPLE6     PNB N1     128297543     0.421
# CSMG3      ON NM      62814853     0.158
# DTEX3      ON NM     273421574     0.245
# ENEV3      ON NM     315416873     0.823
# JHSF3      ON NM     293161476     0.112
# LAME3      ON N1     243346695     0.316
# LCAM3   ON EJ NM     323763077     0.360
# LIGT3      ON NM     303934060     0.227
# LINX3      ON NM     149946789     0.275
# MDIA3      ON NM      83669782     0.160
# MOVI3      ON NM     132113940     0.118
# NEOE3      ON NM     226115915     0.208
# PSSA3      ON NM      93637072     0.241
# RAPT4      PN N1     176269235     0.109
# SAPR11    UNT N2     200991234     0.276
# TRPL4      PN N1     395797044     0.432
